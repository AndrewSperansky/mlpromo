# %% [markdown]
# ### Логин

# %% [markdown]
# curl -X POST http://localhost:8000/api/v1/auth/login \
#   -H "Content-Type: application/json" \
#   -d '{"email": "admin@promo-ml.local", "password": "admin123"}'

# %% [markdown]
# TOKEN="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiIxIiwicm9sZSI6ImFkbWluIiwiZXhwIjoxNzc2MjMzMDU2fQ.wY8ljZheQpUKkmCM0_lKb-CAju1lJS-GY8MmGf-s_As"

# %% [markdown]
# ### Список моделей

# %% [markdown]
# curl -X GET http://localhost:8000/api/v1/ml/models  -H "Authorization: Bearer $TOKEN"

# %% [markdown]
# ### Обучение модели

# %% [markdown]
# curl -X POST http://localhost:8000/api/v1/ml/train  -H "Authorization: Bearer $TOKEN"   -H "Content-Type: application/json"   -d '{"promote": false}'

# %% [markdown]
# ### Прогноз

# %% [markdown]
# curl -X POST http://localhost:8000/api/v1/ml/predict  -H "Authorization: Bearer $TOKEN"  -H "Content-Type: application/json"  -d '{...}'

# %% [markdown]
# ### Drift метрики

# %% [markdown]
# curl -X GET http://localhost:8000/api/v1/ml/monitoring/drift  -H "Authorization: Bearer $TOKEN"

# %% [markdown]
# ### Training metrics (график)

# %% [markdown]
# curl -X GET http://localhost:8000/api/v1/ml/training/metrics   -H "Authorization: Bearer $TOKEN"

# %% [markdown]
# ### Runtime state

# %% [markdown]
# curl -X GET http://localhost:8000/api/v1/system/runtime-state   -H "Authorization: Bearer $TOKEN"

# %% [markdown]
# ### Containers status

# %% [markdown]
# curl -X GET http://localhost:8000/api/v1/system/containers-status   -H "Authorization: Bearer $TOKEN"

# %% [markdown]
# ### Runtime State

# %% [markdown]
# curl http://localhost:8000/api/v1/system/runtime-state | jq

# %% [markdown]
# ### Features order

# %% [markdown]
#  curl http://localhost:8000/api/v1/system/runtime-state | jq '.feature_order'

# %% [markdown]
# ### Metrics

# %% [markdown]
# curl -s http://127.0.0.1:8000/api/v1/system/metrics | jq

# %% [markdown]
# ### Active Model

# %% [markdown]
# curl http://localhost:8000/api/v1/system/runtime-state | jq '.ml_model_id'

# %% [markdown]
# ### Routes Snapsot

# %% [markdown]
# curl http://localhost:8000/routes

# %% [markdown]
# ### Lineage (Происхождение моделей)

# %% [markdown]
# curl -s -X GET http://localhost:8000/api/v1/ml/models/lineage -H "Authorization: Bearer ``$TOKEN" | jq '.'
#
# Только промоушены
#
# curl -s -X GET http://localhost:8000/api/v1/ml/models/lineage -H "Authorization: Bearer $``TOKEN" | jq '.[] | select(.event_type == "promoted")'
#
# Последние 5 событий
#
# curl -s -X GET http://localhost:8000/api/v1/ml/models/lineage -H "Authorization: Bearer $TOKEN" | jq '.[-5:]'
#
# Статистика по типам событий
#
# curl -s -X GET http://localhost:8000/api/v1/ml/models/lineage -H "Authorization: Bearer $TOKEN" | jq 'group_by(.event_type) | map({event: .[0].event_type, count: length})'
